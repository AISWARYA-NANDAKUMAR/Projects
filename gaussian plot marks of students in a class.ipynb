# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
from scipy.stats import norm

# %%
mu=70
sigma=20
pi=0.5
x1=10
x2=20

# %%
def gaussian(x, mu, sigma):
    return 1./(np.sqrt(2.*np.pi)*sig)*np.exp(-np.power((x - mu)/sig, 2.)/2)

# %%
z1=(x1-mu)/sigma
z2=(x2-mu)/sigma

# %%
x = np.arange(z1, z2, 1) # range of x in spec
x_all = np.arange(-100,100,10) # entire range of x, both in and out of spec
# mean = 0, stddev = 1, since Z-transform was calculated
y = norm.pdf(x,0,1)
y2 = norm.pdf(x_all,0,1)

# %%
xcordinates=[0,100,10]
ycordinates=[0,50,1]
fig, ax = plt.subplots(figsize=(10,10))
plt.style.use('fivethirtyeight')
ax.plot(x_all,y2)
plt.xlabel('marks')
plt.ylabel('number of students')
plt.show()
ax.fill_between(x,y,0, alpha=5, color='red')
ax.fill_between(x_all,y2,0, alpha=5)
ax.set_xlim([-100,100])
# Out:
# (-100, 100)
