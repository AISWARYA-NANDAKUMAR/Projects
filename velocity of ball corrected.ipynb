# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
vidcap = cv2.VideoCapture('C:/Users/nobody/Desktop/img/ball.mp4')
def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        cv2.imwrite("image"+str(count)+".jpg", image)
    return hasFrames
sec = 0
frameRate = 0.05
success = getFrame(sec)
while success:
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)

# %%
img1 = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image60.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img1)

# %%
ret1, bw_img1 = cv2.threshold(img1,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img1)

# %%
img2 = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image61.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img2)

# %%
ret2, bw_img2 = cv2.threshold(img2,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img2)

# %%
img3 = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image62.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img3)

# %%
ret3, bw_img3 = cv2.threshold(img3,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img3)

# %%
img4 = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image63.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img4)

# %%
ret4, bw_img4 = cv2.threshold(img4,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img4)

# %%
img5 = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image64.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img5)

# %%
ret5, bw_img5 = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img5)

# %%
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image65.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
plt.imshow(bw_img)
# Out:
# <class 'numpy.ndarray'>
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (720, 1280)

# %%
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image66.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
plt.imshow(bw_img)
# Out:
# <class 'numpy.ndarray'>
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (720, 1280)

# %%
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image67.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
plt.imshow(bw_img)
# Out:
# <class 'numpy.ndarray'>
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (720, 1280)

# %%
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image68.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
plt.imshow(bw_img)
# Out:
# <class 'numpy.ndarray'>
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (720, 1280)

# %%
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image69.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
plt.imshow(bw_img)
# Out:
# <class 'numpy.ndarray'>
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (720, 1280)

# %%
import numpy as np
import matplotlib.pyplot as plt

w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_figures(figures, nrows = 1, ncols=1):
    """Plot a dictionary of figures.

    Parameters
    ----------
    figures : <title, figure> dictionary
    ncols : number of columns of subplots wanted in the display
    nrows : number of rows of subplots wanted in the figure
    """

    fig, axeslist = plt.subplots(ncols=ncols, nrows=nrows)
    for ind,title in zip(range(len(figures)), figures):
        axeslist.ravel()[ind].imshow(figures[title], cmap=plt.jet())
        axeslist.ravel()[ind].set_title(title)
        axeslist.ravel()[ind].set_axis_off()
    plt.tight_layout() # optional



# generation of a dictionary of (title, images)
number_of_im = 20
w=10
h=10
figures = {'im'+str(i): np.random.randint(10, size=(h,w)) for i in range(number_of_im)}

# plot of the images in a figure, with 5 rows and 4 columns
plot_figures(figures, 5, 4)

plt.show()

# %%
import numpy as np
from skimage import io
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image69.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
# plt.imshow(bw_img)

img = io.imread('C:/Users/nobody/Desktop/img/python velocity/image69.jpg', as_gray=True)

left, right, top, bottom = 25, 25, 20, 20
crop = img[top: -bottom, left:- right]
threshold = .85
ball = crop < threshold

rows, cols = np.nonzero(ball)
rightmost = cols.max()
indices = np.nonzero(cols==rightmost)

for r, c, in zip(rows[indices], cols[indices]):
    print('(%d, %d)' % (r + top, c + left))
plt.imshow(bw_img)
# Out:
# (20, 1254)
# (21, 1254)
# (22, 1254)
# (23, 1254)
# (24, 1254)
# (25, 1254)
# (26, 1254)
# (27, 1254)
# (28, 1254)
# (29, 1254)
# (30, 1254)
# (31, 1254)
# (32, 1254)
# (33, 1254)
# (34, 1254)
# (35, 1254)
# (36, 1254)
# (37, 1254)
# (38, 1254)
# (39, 1254)
# (40, 1254)
# (41, 1254)
# (42, 1254)
# (43, 1254)
# (44, 1254)
# (45, 1254)
# (46, 1254)
# (47, 1254)
# (48, 1254)
# (49, 1254)
# (50, 1254)
# (51, 1254)
# (52, 1254)
# (53, 1254)
# (54, 1254)
# (55, 1254)
# (56, 1254)
# (57, 1254)
# (58, 1254)
# (59, 1254)
# (60, 1254)
# (61, 1254)
# (62, 1254)
# (63, 1254)
# (64, 1254)
# (65, 1254)
# (66, 1254)
# (67, 1254)
# (68, 1254)
# (69, 1254)
# (70, 1254)
# (71, 1254)
# (72, 1254)
# (73, 1254)
# (74, 1254)
# (75, 1254)
# (76, 1254)
# (77, 1254)
# (78, 1254)
# (79, 1254)
# (80, 1254)
# (81, 1254)
# (82, 1254)
# (83, 1254)
# (84, 1254)
# (85, 1254)
# (86, 1254)
# (87, 1254)
# (88, 1254)
# (89, 1254)
# (90, 1254)
# (91, 1254)
# (92, 1254)
# (93, 1254)
# (94, 1254)
# (95, 1254)
# ...

# %%
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
img = cv2.imread('C:/Users/nobody/Desktop/img/python velocity/image69.jpg',cv2.IMREAD_GRAYSCALE)
ret, bw_img = cv2.threshold(img,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
data = asarray(bw_img)
print(type(data))
# summarize shape
print(data)
print(data.shape)
plt.imshow(bw_img)

zeros = np.zeros((100, 100), dtype=np.uint8)
zeros[:5,:5] = 255

indices = np.where(zeros == [255])
print indices('bw_img')
coordinates = zip(indices[0], indices[1])
print coordinates('bwimg')
# Out:
#   File "<ipython-input-49-2df82b87df9a>", line 18
#     print indices('bw_img')
#                 ^
# SyntaxError: invalid syntax

# %%
from PIL import Image, ImageFilter, ImageChops
import math

a = [['.','.','.','.','.','.','.'],
      ['.','.','.','.','.','.','.'],
      ['.','.','.','.','.','.','.'],
      ['.','#','#','#','.','.','.'],
      ['.','#','#','#','.','.','.'],
      ['.','.','.','.','.','.','.']]      

sz=(len(a[0]), len(a))
flat_list = [j=='.' for i in a for j in i]
image=Image.new('1', sz)
image.putdata(flat_list)
contour=ImageChops.difference(image, image.filter(ImageFilter.MinFilter(3)))
contour_list=list(contour.getdata())
points=[divmod(i,sz[0]) for i in range(len(contour_list)) if contour_list[i]]
points_x,points_y=zip(*points)
avg=lambda x: sum(x)/len(x)
mean_x=avg(points_x)
mean_y=avg(points_y)
phase=[(math.atan2(points_y[i]-mean_y, points_x[i]-mean_x),i) \
       for i in range(len(points))] 
phase.sort()
for i in range(len(points)):
    print(*points[phase[i][1]])
# Out:
# 2 1
# 2 0
# 3 0
# 4 0
# 5 0
# 5 1
# 5 2
# 5 3
# 5 4
# 4 4
# 3 4
# 2 4
# 2 3
# 2 2
