# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from numpy import asarray
import matplotlib.image as img
import cv2
from skimage import io

vidcap = cv2.VideoCapture('C:/Users/nobody/Desktop/img/ball.mp4')
def getFrame(sec):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        cv2.imwrite("image"+str(count)+".jpg", image)
    return hasFrames
sec = 0
frameRate = 0.05
success = getFrame(sec)
count=1
while success:
    sec = sec + frameRate
    sec = round(sec, 2)
    success = getFrame(sec)
    count=count+1

# %%
img1 = cv2.imread("C:/Users/nobody/Desktop/velocity/image142.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img1)
ret, bw_img1 = cv2.threshold(img1,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img1)

# %%
img2 = cv2.imread("C:/Users/nobody/Desktop/velocity/image143.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img2)
ret, bw_img2 = cv2.threshold(img2,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img2)

# %%
img3 = cv2.imread("C:/Users/nobody/Desktop/velocity/image144.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img3)
ret, bw_img3 = cv2.threshold(img1,200,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
plt.imshow(bw_img3)
